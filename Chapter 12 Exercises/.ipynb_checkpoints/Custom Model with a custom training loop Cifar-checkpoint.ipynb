# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading the cifar dataset
cifar_data = tf.keras.datasets.cifar10.load_data()
cifar_scaled_train = cifar_data[0][0] / 255
cifar_scaled_test = cifar_data[1][0] / 255

# %%
# Splitting up the data\
x_train = cifar_scaled_train
y_train = cifar_data[0][1]
x_test = cifar_scaled_test
y_test = cifar_data[1][1]

# Splitting the validation and training data
x_val = x_train[40000:]
y_val = y_train[40000:]
x_train = x_train[:40000]
y_train = y_train[:40000]

# %%
# Making a regularizer
l2_reg = tf.keras.regularizers.l2(0.05)

# %%
# Here we create a custom model that does the same thing as above
class SeluModel(tf.keras.Model):
    
    def __init__(self, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.hidden = [tf.keras.layers.Dense(100, activation="selu", 
        kernel_initializer="lecun_normal", kernel_regularizer=l2_reg) for _ in range(20)]
        self.out = tf.keras.layers.Dense(output_dim, activation="softmax")
        
    def build(self, batch_input_shape):
        # The first shape would be the batch size
        self.input_layer = tf.keras.layers.Flatten(input_shape=batch_input_shape[1:])
        super().build(batch_input_shape)
        
    def call(self, inputs):
        batch_of_pixel_grids = inputs
        # Here we should be handling the batch of pictures so no need to cut off to only the shape
        Z = self.input_layer(batch_of_pixel_grids)
        for layer in self.hidden:
            Z = layer(Z)
        return self.out(Z)

# %%
model = SeluModel(10)
model.build(cifar_scaled_train.shape)
model.summary()
# Out:
# Model: "selu_model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_63 (Dense)             multiple                  307300
# _________________________________________________________________
# dense_64 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_65 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_66 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_67 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_68 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_69 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_70 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_71 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_72 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_73 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_74 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_75 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_76 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_77 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_78 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_79 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_80 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_81 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_82 (Dense)             multiple                  10100
# _________________________________________________________________
# dense_83 (Dense)             multiple                  1010
# _________________________________________________________________
# flatten_3 (Flatten)          multiple                  0
# =================================================================
# Total params: 500,210
# Trainable params: 500,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Metrics and hyperparameters for the model
n_epochs = 5
batch_size = 32
n_steps = len(x_train) // batch_size
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.01)
loss_fn = tf.keras.losses.sparse_categorical_crossentropy
mean_loss = tf.keras.metrics.Mean()
metrics = [tf.keras.metrics.MeanAbsoluteError()]

# %%
# Random Batching function to get shuffled batches on each interation
def random_batch(x, y, batch_size=32):
    idx = np.random.randint(len(x), size=batch_size)
    return x[idx], y[idx]

# %%
# Printing function
def print_status_bar(iteration, total, loss, metrics=None):
    metrics = " - ".join(["{}: {:.4f}".format(m.name, m.result())
                        for m in [loss] + (metrics or [])])
    end = "" if iteration < total else "\n"
    print("\r{}/{} - ".format(iteration, total) + metrics,
        end=end)

# %%
# Custom training loop (Shitty version)
for epoch in range(1, n_epochs + 1):
    print("Epoch {}/{}".format(epoch, n_epochs))
    for step in range(1, n_steps + 1):
        X_batch, y_batch = random_batch(x_train, y_train)
        with tf.GradientTape() as tape:
            y_pred = model3(X_batch, training=True)
            main_loss = tf.reduce_mean(loss_fn(y_batch, y_pred))
            loss = tf.add_n([main_loss] + model3.losses)
        gradients = tape.gradient(loss, model3.trainable_variables)
        optimizer.apply_gradients(zip(gradients,
model3.trainable_variables))
        mean_loss(loss)
        for metric in metrics:
            metric(y_batch, y_pred)
        print_status_bar(step * batch_size, len(y_train), mean_loss,
metrics)
    print_status_bar(len(y_train), len(y_train), mean_loss, metrics)
for metric in [mean_loss] + metrics:metric.reset_states()
# Out:
# Epoch 1/5
# 2048/40000 - mean: 2.5274 - mean_absolute_error: 4.3511
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-1db054c967e1> in <module>
#       9             loss = tf.add_n([main_loss] + model3.losses)
#      10         gradients = tape.gradient(loss, model3.trainable_variables)
# ---> 11         optimizer.apply_gradients(zip(gradients,
#      12 model3.trainable_variables))
#      13         mean_loss(loss)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     634       # Create iteration if necessary.
#     635       with ops.init_scope():
# --> 636         self._create_all_weights(var_list)
#     637
#     638       if not grads_and_vars:
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _create_all_weights(self, var_list)
#     821     _ = self.iterations
#     822     self._create_hypers()
# --> 823     self._create_slots(var_list)
#     824
#     825   def __getattribute__(self, name):
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/nadam.py in _create_slots(self, var_list)
#      99     for var in var_list:
#     100       # Create slots for the first moments.
# --> 101       self.add_slot(var, 'm')
#     102     for var in var_list:
#     103       # Create slots for the second moments.
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in add_slot(self, var, slot_name, initializer, shape)
#     880     var_key = _var_key(var)
#     881     slot_dict = self._slots.setdefault(var_key, {})
# --> 882     weight = slot_dict.get(slot_name, None)
#     883     if weight is None:
#     884       if isinstance(initializer, str) or callable(initializer):
#
# KeyboardInterrupt:

# %%
# Custom Training loop, Aurelien's version (the correct version)
# Still don't really know if this one is all that good either, lets fix this up as an exercise
from tqdm import trange
from collections import OrderedDict
# Keeping track of the overall progress with tqdm
with trange(1, n_epochs + 1, desc="All epochs") as epochs:
    for epoch in epochs:
        with trange(1, n_steps + 1, desc="Epoch {}/{}".format(epoch, n_epochs)) as steps:
            for step in steps:
                X_batch, y_batch = random_batch(x_train, y_train)
                # Here we are tracking the mathematical operators for the
                # back-prop calculus with epsilon gradient approximations
                with tf.GradientTape() as tape:
                    y_pred = model(X_batch)
                    main_loss = tf.reduce_mean(loss_fn(y_batch, y_pred))
                    loss = tf.add_n([main_loss] + model.losses)
                gradients = tape.gradient(loss, model.trainable_variables)
                optimizer.apply_gradients(zip(gradients, model.trainable_variables))
                for variable in model.variables:
                    if variable.constraint is not None:
                        variable.assign(variable.constraint(variable))                    
                status = OrderedDict()
                mean_loss(loss)
                status["loss"] = mean_loss.result().numpy()
                for metric in metrics:
                    metric(y_batch, y_pred)
                    status[metric.name] = metric.result().numpy()
                steps.set_postfix(status)
            y_pred = model(x_val)
            status["val_loss"] = np.mean(loss_fn(y_val, y_pred))
            status["val_accuracy"] = np.mean(tf.keras.metrics.sparse_categorical_accuracy(
                tf.constant(y_val, dtype=np.float32), y_pred))
            steps.set_postfix(status)
        for metric in [mean_loss] + metrics:
            metric.reset_states()
# Out:
# All epochs:   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1/5:   0%|          | 0/1250 [00:00<?, ?it/s]
# Epoch 1/5:   0%|          | 0/1250 [00:00<?, ?it/s, loss=3.1e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 0/1250 [00:00<?, ?it/s, loss=3.1e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 2/1250 [00:00<01:24, 14.74it/s, loss=3.1e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 2/1250 [00:00<01:24, 14.74it/s, loss=3.1e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 2/1250 [00:00<01:24, 14.74it/s, loss=3.1e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 4/1250 [00:00<01:20, 15.44it/s, loss=3.1e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 4/1250 [00:00<01:20, 15.44it/s, loss=3.09e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 4/1250 [00:00<01:20, 15.44it/s, loss=3.09e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 6/1250 [00:00<01:19, 15.60it/s, loss=3.09e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 6/1250 [00:00<01:19, 15.60it/s, loss=3.09e+3, mean_absolute_error=4.41]
# Epoch 1/5:   0%|          | 6/1250 [00:00<01:19, 15.60it/s, loss=3.09e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 8/1250 [00:00<01:19, 15.60it/s, loss=3.09e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 8/1250 [00:00<01:19, 15.60it/s, loss=3.08e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 8/1250 [00:00<01:19, 15.60it/s, loss=3.08e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 10/1250 [00:00<01:19, 15.66it/s, loss=3.08e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 10/1250 [00:00<01:19, 15.66it/s, loss=3.08e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 10/1250 [00:00<01:19, 15.66it/s, loss=3.08e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 12/1250 [00:00<01:22, 15.05it/s, loss=3.08e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 12/1250 [00:00<01:22, 15.05it/s, loss=3.07e+3, mean_absolute_error=4.42]
# Epoch 1/5:   1%|          | 12/1250 [00:00<01:22, 15.05it/s, loss=3.07e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 14/1250 [00:00<01:21, 15.14it/s, loss=3.07e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 14/1250 [00:00<01:21, 15.14it/s, loss=3.07e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|          | 14/1250 [00:01<01:21, 15.14it/s, loss=3.07e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|▏         | 16/1250 [00:01<01:21, 15.14it/s, loss=3.07e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|▏         | 16/1250 [00:01<01:21, 15.14it/s, loss=3.06e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|▏         | 16/1250 [00:01<01:21, 15.14it/s, loss=3.06e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|▏         | 18/1250 [00:01<01:22, 14.95it/s, loss=3.06e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|▏         | 18/1250 [00:01<01:22, 14.95it/s, loss=3.06e+3, mean_absolute_error=4.41]
# Epoch 1/5:   1%|▏         | 18/1250 [00:01<01:22, 14.95it/s, loss=3.06e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 20/1250 [00:01<01:21, 15.02it/s, loss=3.06e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 20/1250 [00:01<01:21, 15.02it/s, loss=3.06e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 20/1250 [00:01<01:21, 15.02it/s, loss=3.05e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 22/1250 [00:01<01:22, 14.91it/s, loss=3.05e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 22/1250 [00:01<01:22, 14.91it/s, loss=3.05e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 22/1250 [00:01<01:22, 14.91it/s, loss=3.05e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 24/1250 [00:01<01:22, 14.81it/s, loss=3.05e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 24/1250 [00:01<01:22, 14.81it/s, loss=3.05e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 24/1250 [00:01<01:22, 14.81it/s, loss=3.04e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 26/1250 [00:01<01:22, 14.80it/s, loss=3.04e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 26/1250 [00:01<01:22, 14.80it/s, loss=3.04e+3, mean_absolute_error=4.41]
# Epoch 1/5:   2%|▏         | 26/1250 [00:01<01:22, 14.80it/s, loss=3.04e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▎         | 44/1250 [00:02<01:21, 14.73it/s, loss=3e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▎         | 44/1250 [00:02<01:21, 14.73it/s, loss=3e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▎         | 44/1250 [00:03<01:21, 14.73it/s, loss=3e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▎         | 46/1250 [00:03<01:21, 14.82it/s, loss=3e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▎         | 46/1250 [00:03<01:21, 14.82it/s, loss=2.99e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▎         | 46/1250 [00:03<01:21, 14.82it/s, loss=2.99e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 48/1250 [00:03<01:20, 14.90it/s, loss=2.99e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 48/1250 [00:03<01:20, 14.90it/s, loss=2.99e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 48/1250 [00:03<01:20, 14.90it/s, loss=2.99e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 50/1250 [00:03<01:19, 15.08it/s, loss=2.99e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 50/1250 [00:03<01:19, 15.08it/s, loss=2.98e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 50/1250 [00:03<01:19, 15.08it/s, loss=2.98e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 52/1250 [00:03<01:18, 15.31it/s, loss=2.98e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 52/1250 [00:03<01:18, 15.31it/s, loss=2.98e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 52/1250 [00:03<01:18, 15.31it/s, loss=2.98e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 54/1250 [00:03<01:16, 15.57it/s, loss=2.98e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 54/1250 [00:03<01:16, 15.57it/s, loss=2.98e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 54/1250 [00:03<01:16, 15.57it/s, loss=2.97e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 56/1250 [00:03<01:18, 15.18it/s, loss=2.97e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 56/1250 [00:03<01:18, 15.18it/s, loss=2.97e+3, mean_absolute_error=4.41]
# Epoch 1/5:   4%|▍         | 56/1250 [00:03<01:18, 15.18it/s, loss=2.97e+3, mean_absolute_error=4.41]
# Epoch 1/5:   5%|▍         | 58/1250 [00:03<01:18, 15.19it/s, loss=2.97e+3, mean_absolute_error=4.41]
# Epoch 1/5:   5%|▍         | 58/1250 [00:03<01:18, 15.19it/s, loss=2.97e+3, mean_absolute_error=4.41]
# Epoch 1/5:   5%|▍         | 58/1250 [00:03<01:18, 15.19it/s, loss=2.96e+3, mean_absolute_error=4.41]
# Epoch 1/5:   8%|▊         | 106/1250 [00:07<01:14, 15.29it/s, loss=2.86e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▊         | 108/1250 [00:07<01:14, 15.39it/s, loss=2.86e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▊         | 108/1250 [00:07<01:14, 15.39it/s, loss=2.86e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▊         | 108/1250 [00:07<01:14, 15.39it/s, loss=2.86e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 110/1250 [00:07<01:13, 15.59it/s, loss=2.86e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 110/1250 [00:07<01:13, 15.59it/s, loss=2.85e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 110/1250 [00:07<01:13, 15.59it/s, loss=2.85e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 112/1250 [00:07<01:14, 15.37it/s, loss=2.85e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 112/1250 [00:07<01:14, 15.37it/s, loss=2.85e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 112/1250 [00:07<01:14, 15.37it/s, loss=2.85e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 114/1250 [00:07<01:14, 15.34it/s, loss=2.85e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 114/1250 [00:07<01:14, 15.34it/s, loss=2.84e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 114/1250 [00:07<01:14, 15.34it/s, loss=2.84e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 116/1250 [00:07<01:15, 14.96it/s, loss=2.84e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 116/1250 [00:07<01:15, 14.96it/s, loss=2.84e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 116/1250 [00:07<01:15, 14.96it/s, loss=2.84e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 118/1250 [00:07<01:16, 14.89it/s, loss=2.84e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 118/1250 [00:07<01:16, 14.89it/s, loss=2.84e+3, mean_absolute_error=4.41]
# Epoch 1/5:   9%|▉         | 118/1250 [00:07<01:16, 14.89it/s, loss=2.83e+3, mean_absolute_error=4.41]
# Epoch 1/5:  10%|▉         | 120/1250 [00:07<01:15, 15.06it/s, loss=2.83e+3, mean_absolute_error=4.41]
# Epoch 1/5:  10%|▉         | 120/1250 [00:07<01:15, 15.06it/s, loss=2.83e+3, mean_absolute_error=4.41]
# Epoch 1/5:  10%|▉         | 120/1250 [00:08<01:15, 15.06it/s, loss=2.83e+3, mean_absolute_error=4.41]
# Epoch 1/5:  10%|▉         | 122/1250 [00:08<01:15, 14.95it/s, loss=2.83e+3, mean_absolute_error=4.41]
# Epoch 1/5:  17%|█▋        | 216/1250 [00:14<01:07, 15.26it/s, loss=2.65e+3, mean_absolute_error=4.41]
# Epoch 1/5:  17%|█▋        | 216/1250 [00:14<01:07, 15.26it/s, loss=2.65e+3, mean_absolute_error=4.41]
# Epoch 1/5:  17%|█▋        | 218/1250 [00:14<01:07, 15.22it/s, loss=2.65e+3, mean_absolute_error=4.41]
# Epoch 1/5:  17%|█▋        | 218/1250 [00:14<01:07, 15.22it/s, loss=2.64e+3, mean_absolute_error=4.41]
# Epoch 1/5:  17%|█▋        | 218/1250 [00:14<01:07, 15.22it/s, loss=2.64e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 220/1250 [00:14<01:07, 15.32it/s, loss=2.64e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 220/1250 [00:14<01:07, 15.32it/s, loss=2.64e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 220/1250 [00:14<01:07, 15.32it/s, loss=2.64e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 222/1250 [00:14<01:07, 15.26it/s, loss=2.64e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 222/1250 [00:14<01:07, 15.26it/s, loss=2.64e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 222/1250 [00:14<01:07, 15.26it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 224/1250 [00:14<01:09, 14.84it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 224/1250 [00:14<01:09, 14.84it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 224/1250 [00:14<01:09, 14.84it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 226/1250 [00:14<01:07, 15.06it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 226/1250 [00:14<01:07, 15.06it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 226/1250 [00:14<01:07, 15.06it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 228/1250 [00:14<01:06, 15.34it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 228/1250 [00:15<01:06, 15.34it/s, loss=2.63e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 228/1250 [00:15<01:06, 15.34it/s, loss=2.62e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 230/1250 [00:15<01:06, 15.41it/s, loss=2.62e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 230/1250 [00:15<01:06, 15.41it/s, loss=2.62e+3, mean_absolute_error=4.41]
# Epoch 1/5:  18%|█▊        | 230/1250 [00:15<01:06, 15.41it/s, loss=2.62e+3, mean_absolute_error=4.41]
# Epoch 1/5:  25%|██▍       | 310/1250 [00:20<01:00, 15.56it/s, loss=2.49e+3, mean_absolute_error=4.41]
# Epoch 1/5:  25%|██▍       | 310/1250 [00:20<01:00, 15.56it/s, loss=2.49e+3, mean_absolute_error=4.41]
# Epoch 1/5:  25%|██▍       | 312/1250 [00:20<00:59, 15.65it/s, loss=2.49e+3, mean_absolute_error=4.41]
# Epoch 1/5:  25%|██▍       | 312/1250 [00:20<00:59, 15.65it/s, loss=2.48e+3, mean_absolute_error=4.41]
# Epoch 1/5:  25%|██▍       | 312/1250 [00:20<00:59, 15.65it/s, loss=2.48e+3, mean_absolute_error=4.41]
# Epoch 1/5:  25%|██▌       | 314/1250 [00:20<00:59, 15.72it/s, loss=2.48e+3, mean_absolute_error=4.41]
# ...
# Epoch 1/5:  92%|█████████▏| 1150/1250 [01:14<00:06, 16.12it/s, loss=1.62e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1152/1250 [01:14<00:06, 16.00it/s, loss=1.62e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1152/1250 [01:14<00:06, 16.00it/s, loss=1.62e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1152/1250 [01:14<00:06, 16.00it/s, loss=1.62e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1154/1250 [01:14<00:05, 16.06it/s, loss=1.62e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1154/1250 [01:14<00:05, 16.06it/s, loss=1.62e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1154/1250 [01:14<00:05, 16.06it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1156/1250 [01:14<00:05, 16.08it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1156/1250 [01:14<00:05, 16.08it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  92%|█████████▏| 1156/1250 [01:14<00:05, 16.08it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1158/1250 [01:14<00:05, 16.07it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1158/1250 [01:14<00:05, 16.07it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1158/1250 [01:14<00:05, 16.07it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1160/1250 [01:14<00:05, 15.97it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1160/1250 [01:14<00:05, 15.97it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1160/1250 [01:14<00:05, 15.97it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1162/1250 [01:14<00:05, 15.99it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1162/1250 [01:14<00:05, 15.99it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1162/1250 [01:15<00:05, 15.99it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1164/1250 [01:15<00:05, 15.98it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1164/1250 [01:15<00:05, 15.98it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1164/1250 [01:15<00:05, 15.98it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1166/1250 [01:15<00:05, 15.96it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1166/1250 [01:15<00:05, 15.96it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1166/1250 [01:15<00:05, 15.96it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1168/1250 [01:15<00:05, 15.89it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1168/1250 [01:15<00:05, 15.89it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  93%|█████████▎| 1168/1250 [01:15<00:05, 15.89it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▎| 1170/1250 [01:15<00:04, 16.00it/s, loss=1.61e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▎| 1170/1250 [01:15<00:04, 16.00it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▎| 1170/1250 [01:15<00:04, 16.00it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1172/1250 [01:15<00:04, 16.11it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1172/1250 [01:15<00:04, 16.11it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1172/1250 [01:15<00:04, 16.11it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1174/1250 [01:15<00:04, 16.19it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1174/1250 [01:15<00:04, 16.19it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1174/1250 [01:15<00:04, 16.19it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1176/1250 [01:15<00:04, 16.16it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1176/1250 [01:15<00:04, 16.16it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1176/1250 [01:15<00:04, 16.16it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1178/1250 [01:15<00:04, 16.10it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1178/1250 [01:15<00:04, 16.10it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1178/1250 [01:16<00:04, 16.10it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1180/1250 [01:16<00:04, 16.01it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1180/1250 [01:16<00:04, 16.01it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  94%|█████████▍| 1180/1250 [01:16<00:04, 16.01it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1182/1250 [01:16<00:04, 15.96it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1182/1250 [01:16<00:04, 15.96it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1182/1250 [01:16<00:04, 15.96it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1184/1250 [01:16<00:04, 15.96it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1184/1250 [01:16<00:04, 15.96it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1184/1250 [01:16<00:04, 15.96it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1186/1250 [01:16<00:04, 15.88it/s, loss=1.6e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1186/1250 [01:16<00:04, 15.88it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▍| 1186/1250 [01:16<00:04, 15.88it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1188/1250 [01:16<00:03, 15.93it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1188/1250 [01:16<00:03, 15.93it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1188/1250 [01:16<00:03, 15.93it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1190/1250 [01:16<00:03, 15.93it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1190/1250 [01:16<00:03, 15.93it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1190/1250 [01:16<00:03, 15.93it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1192/1250 [01:16<00:03, 15.96it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1192/1250 [01:16<00:03, 15.96it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  95%|█████████▌| 1192/1250 [01:16<00:03, 15.96it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1194/1250 [01:16<00:03, 15.95it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1194/1250 [01:16<00:03, 15.95it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1194/1250 [01:17<00:03, 15.95it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1196/1250 [01:17<00:03, 15.98it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1196/1250 [01:17<00:03, 15.98it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1196/1250 [01:17<00:03, 15.98it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1198/1250 [01:17<00:03, 15.98it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1198/1250 [01:17<00:03, 15.98it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1198/1250 [01:17<00:03, 15.98it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1200/1250 [01:17<00:03, 15.99it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1200/1250 [01:17<00:03, 15.99it/s, loss=1.59e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1200/1250 [01:17<00:03, 15.99it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1202/1250 [01:17<00:03, 15.99it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1202/1250 [01:17<00:03, 15.99it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▌| 1202/1250 [01:17<00:03, 15.99it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▋| 1204/1250 [01:17<00:02, 16.02it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▋| 1204/1250 [01:17<00:02, 16.02it/s, loss=1582.8, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▋| 1204/1250 [01:17<00:02, 16.02it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▋| 1206/1250 [01:17<00:02, 16.02it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▋| 1206/1250 [01:17<00:02, 16.02it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  96%|█████████▋| 1206/1250 [01:17<00:02, 16.02it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1208/1250 [01:17<00:02, 16.01it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1208/1250 [01:17<00:02, 16.01it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1208/1250 [01:17<00:02, 16.01it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1210/1250 [01:17<00:02, 15.88it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1210/1250 [01:17<00:02, 15.88it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1210/1250 [01:18<00:02, 15.88it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1212/1250 [01:18<00:02, 15.92it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1212/1250 [01:18<00:02, 15.92it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1212/1250 [01:18<00:02, 15.92it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1214/1250 [01:18<00:02, 16.04it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1214/1250 [01:18<00:02, 16.04it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1214/1250 [01:18<00:02, 16.04it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1216/1250 [01:18<00:02, 15.97it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1216/1250 [01:18<00:02, 15.97it/s, loss=1.58e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1216/1250 [01:18<00:02, 15.97it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1218/1250 [01:18<00:02, 15.96it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1218/1250 [01:18<00:02, 15.96it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  97%|█████████▋| 1218/1250 [01:18<00:02, 15.96it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1220/1250 [01:18<00:01, 16.05it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1220/1250 [01:18<00:01, 16.05it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1220/1250 [01:18<00:01, 16.05it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1222/1250 [01:18<00:01, 16.13it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1222/1250 [01:18<00:01, 16.13it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1222/1250 [01:18<00:01, 16.13it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1224/1250 [01:18<00:01, 16.07it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1224/1250 [01:18<00:01, 16.07it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1224/1250 [01:18<00:01, 16.07it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1226/1250 [01:18<00:01, 16.13it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1226/1250 [01:18<00:01, 16.13it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1226/1250 [01:19<00:01, 16.13it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1228/1250 [01:19<00:01, 16.00it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1228/1250 [01:19<00:01, 16.00it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1228/1250 [01:19<00:01, 16.00it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1230/1250 [01:19<00:01, 15.90it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1230/1250 [01:19<00:01, 15.90it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  98%|█████████▊| 1230/1250 [01:19<00:01, 15.90it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▊| 1232/1250 [01:19<00:01, 15.92it/s, loss=1.57e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▊| 1232/1250 [01:19<00:01, 15.92it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▊| 1232/1250 [01:19<00:01, 15.92it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▊| 1234/1250 [01:19<00:01, 15.84it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▊| 1234/1250 [01:19<00:01, 15.84it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▊| 1234/1250 [01:19<00:01, 15.84it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1236/1250 [01:19<00:00, 15.94it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1236/1250 [01:19<00:00, 15.94it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1236/1250 [01:19<00:00, 15.94it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1238/1250 [01:19<00:00, 15.97it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1238/1250 [01:19<00:00, 15.97it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1238/1250 [01:19<00:00, 15.97it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1240/1250 [01:19<00:00, 15.93it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1240/1250 [01:19<00:00, 15.93it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1240/1250 [01:19<00:00, 15.93it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1242/1250 [01:19<00:00, 15.99it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1242/1250 [01:19<00:00, 15.99it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5:  99%|█████████▉| 1242/1250 [01:20<00:00, 15.99it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1244/1250 [01:20<00:00, 15.79it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1244/1250 [01:20<00:00, 15.79it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1244/1250 [01:20<00:00, 15.79it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1246/1250 [01:20<00:00, 15.79it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1246/1250 [01:20<00:00, 15.79it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1246/1250 [01:20<00:00, 15.79it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1248/1250 [01:20<00:00, 15.86it/s, loss=1.56e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1248/1250 [01:20<00:00, 15.86it/s, loss=1.55e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|█████████▉| 1248/1250 [01:20<00:00, 15.86it/s, loss=1.55e+3, mean_absolute_error=4.42]
# Epoch 1/5: 100%|██████████| 1250/1250 [01:20<00:00, 15.54it/s, loss=1.55e+3, mean_absolute_error=4.42]
# All epochs:   0%|          | 0/5 [01:20<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-908c36ab74cc> in <module>
#      29             y_pred = model(x_val)
#      30             status["val_loss"] = np.mean(loss_fn(y_val, y_pred))
# ---> 31             status["val_accuracy"] = np.mean(keras.metrics.sparse_categorical_accuracy(
#      32                 tf.constant(y_val, dtype=np.float32), y_pred))
#      33             steps.set_postfix(status)
#
# NameError: name 'keras' is not defined
